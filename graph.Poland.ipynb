# %% [markdown]
# ## Technikalia

# %%
try:

    def connect():
        import psycopg2
        return psycopg2.connect(
            host="localhost",
            database="musicbrainz",
            user="postgres",
            password="123"
        )
    
    CONNECTION = connect()

    print("Połączono z bazą danych")

    def SQL(q):
        from pandas import read_sql_query
        import warnings
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore', category=UserWarning)
            
            # UserWarning: pandas only supports SQLAlchemy connectable 
            # (engine/connection) or database string URI or sqlite3 DBAPI2 connection. 
            # Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
            
            return read_sql_query(q, CONNECTION)
    
except Exception as e:
    print("Nie udało się połączyć z bazą danych. Błąd:", e)
# Out:
# Połączono z bazą danych

# %% [markdown]
# ## Relacje

# %% [markdown]
# Graf polskich artystów i ich utworów

# %%
SQL("""

    DROP TABLE IF EXISTS features_pl;

    CREATE TABLE features_pl AS
    WITH pl AS (SELECT id FROM musicbrainz.area WHERE UPPER(name)='POLAND')
    SELECT
        tra.id AS track, art.id AS artist
    
    FROM musicbrainz.track AS tra
    
    LEFT JOIN musicbrainz.artist_credit AS cre 
        ON cre.id = tra.artist_credit
    LEFT JOIN musicbrainz.artist_credit_name AS cre_many2many 
        ON cre.id = cre_many2many.artist_credit
    LEFT JOIN musicbrainz.artist AS art
        ON art.id = cre_many2many.artist
    
    WHERE art.area IN (SELECT id FROM pl);         

    SELECT 
        column_name, data_type, is_nullable
    FROM 
        information_schema.columns
    WHERE 
        table_name = 'features_pl';
    
""").set_index('column_name')
# Out:
#             data_type is_nullable
# column_name
# track         integer         YES
# artist        integer         YES

# %% [markdown]
# ## Case study

# %%
artist = "Maryla Rodowicz"

# %%
tracks = SQL(f"""

    WITH

        target AS (
            SELECT id 
            FROM musicbrainz.artist 
            WHERE UPPER(name) 
            LIKE '%{artist.upper()}%'
        ),
    
        output AS (
            SELECT track
            FROM features_pl
            WHERE artist IN (SELECT id FROM target)
        ),

        colab AS (
            SELECT DISTINCT artist FROM features_pl 
            WHERE track IN (SELECT track FROM output)
        )
    
    SELECT * FROM features_pl 
        WHERE artist IN (SELECT artist FROM colab);

""")

tracks
# Out:
#          track  artist
# 0       590139   52119
# 1       590144   52119
# 2       951373   84953
# 3       951377   84953
# 4       951378   84953
# ...        ...     ...
# 5748  17802621  937404
# 5749  17802622  937404
# 5750  17802623  937404
# 5751  17802624  937404
# 5752  17802625  937404
#
# [5753 rows x 2 columns]

# %%
artist_labels = SQL(f"""

    WITH

        target AS (
            SELECT id 
            FROM musicbrainz.artist 
            WHERE UPPER(name) 
            LIKE '%{artist.upper()}%'
        ),
    
        output AS (
            SELECT track
            FROM features_pl
            WHERE artist IN (SELECT id FROM target)
        ),

        colab AS (
            SELECT DISTINCT artist FROM features_pl 
            WHERE track IN (SELECT track FROM output)
        )
    
    SELECT id, name FROM musicbrainz.artist
        WHERE id IN (SELECT artist FROM colab);

""").set_index('id')

artist_labels
# Out:
#                           name
# id
# 450057       Seweryn Krajewski
# 554378  Patrycja Kosiarkiewicz
# 807100       Sławek Uniatowski
# 52119           Czesław Niemen
# 628471        Renata Dąbkowska
# 573264    Maciej Miecznikowski
# 573263         Andrzej Lampert
# 103209           Edyta Geppert
# 370987        Kasia Cerekwicka
# 160812       Ryszard Rynkowski
# 161038          Marek Grechuta
# 103212        Piotr Szczepanik
# 476319                K.A.S.A.
# 573265  Małgorzata Kożuchowska
# 329066               Zakopower
# 263473              Stan Borys
# 118005     Justyna Steczkowska
# 611801      Grzegorz Markowski
# 84953       Edyta Bartosiewicz
# 937404                 Donatan
# 160803         Maryla Rodowicz
# 287258     Krzysztof Kiljański
# 128256        Natalia Kukulska
# 117912                Nosowska
# 55126             Irena Santor
# 336999                Alibabki

# %%
track_labels = SQL(f"""

    WITH

        target AS (
            SELECT id 
            FROM musicbrainz.artist 
            WHERE UPPER(name) 
            LIKE '%{artist.upper()}%'
        ),
    
        output AS (
            SELECT track
            FROM features_pl
            WHERE artist IN (SELECT id FROM target)
        ),

        colab AS (
            SELECT DISTINCT artist FROM features_pl 
            WHERE track IN (SELECT track FROM output)
        )
    
    SELECT 
        DISTINCT features_pl.track AS id, 
        track.name, release.name as release
        
        FROM features_pl
    LEFT JOIN musicbrainz.track AS track
        ON track.id = features_pl.track

    LEFT JOIN musicbrainz.medium AS med
        ON med.id = track.medium

    LEFT JOIN musicbrainz.release AS release
        ON release.id = med.release

    WHERE artist IN (SELECT artist FROM colab);

""").set_index('id')

track_labels
# Out:
#                                 name                             release
# id
# 590133                  Pod Papugami  Pod Papugami - Największe Przeboje
# 590134         Dziwny jest ten świat  Pod Papugami - Największe Przeboje
# 590135               Sen o Warszawie  Pod Papugami - Największe Przeboje
# 590136    Czy mnie jeszcze pamiętasz  Pod Papugami - Największe Przeboje
# 590137                        Sukces  Pod Papugami - Największe Przeboje
# ...                              ...                                 ...
# 46205395  Czy Mnie Jeszcze Pamiętasz                  Pamiętam Ten Dzień
# 46205396         Hej Dziewczyno, Hej                  Pamiętam Ten Dzień
# 46205397             Sen O Warszawie                  Pamiętam Ten Dzień
# 46205398                 Wspomnienie                  Pamiętam Ten Dzień
# 46582613            Zawsze obok mnie           CD Club Promo Only 7/2013
#
# [5700 rows x 2 columns]

# %% [markdown]
# ### Więcej dancyh

# %%
import pandas as pd

# %% [markdown]
# ### Popularność

# %%
import spotipy, requests
from spotipy.oauth2 import SpotifyClientCredentials

def load_creds():
    from dotenv import load_dotenv
    load_dotenv()
    
load_creds()

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
spotify_searches = tracks.merge(artist_labels.reset_index(), left_on='artist', right_on='id', how='left', suffixes=('', '_artist'))
spotify_searches = spotify_searches.merge(track_labels.reset_index(), left_on='track', right_on='id', how='left', suffixes=('', '_track'))
spotify_searches = spotify_searches.rename(columns={'name_track': 'title'})
spotify_searches = spotify_searches.drop_duplicates(subset=['track', 'title']).drop(columns=['id', 'id_track', 'artist'])
spotify_ids, popularity, release_name = ([], [], [])
for i, row in spotify_searches.iterrows():
    
    q = f"artist:{row['name']} track:{row['title']} album:{row['release']}"
    results = sp.search(q=q, type='track')
    
    items = results['tracks']['items']
    
    print(f"{i} {q}: {len(items)}")
    
    if items:
        track = items[0]
        spotify_ids.append(track['id'])
        track_info = sp.track(track['id'])
        popularity.append(track_info['popularity'])
        release_name.append(track_info['album']['name'])
    else:
        spotify_ids.append(None)
        popularity.append(None)
        release_name.append(None)

spotify_searches['spotify_id'] = spotify_ids
spotify_searches['popularity'] = popularity
spotify_searches['release_name'] = release_name
# Out:
# 0 artist:Czesław Niemen track:Stoję w oknie album:Pod Papugami - Największe Przeboje: 0
# 1 artist:Czesław Niemen track:Jeszcze swój egzamin zdasz album:Pod Papugami - Największe Przeboje: 0
# 2 artist:Edyta Bartosiewicz track:Skłamałam album:Dziecko: 0
# 3 artist:Edyta Bartosiewicz track:Boogie czyli zemsta słodka jest album:Dziecko: 0
# 4 artist:Edyta Bartosiewicz track:Coś zmieniło się? album:Dziecko: 0
# 5 artist:Edyta Bartosiewicz track:Nie jak przyjaciel album:Dziecko: 0
# 6 artist:Edyta Bartosiewicz track:Dobrze nam album:Dziecko: 0
# 7 artist:Edyta Geppert track:Nie wierzę piosence album:Wierzę piosence: 0
# 8 artist:Edyta Geppert track:Niewysłowiona album:Wierzę piosence: 0
# 9 artist:Edyta Geppert track:Zdradzonym i bezbronnym album:Wierzę piosence: 0
# 10 artist:Edyta Geppert track:Jaka róża taki cierń album:Wierzę piosence: 0
# 11 artist:Edyta Geppert track:Nie jest źle album:Wierzę piosence: 0
# 12 artist:Piotr Szczepanik track:Żółte kalendarze album:Złote przeboje: 0
# 13 artist:Piotr Szczepanik track:Każdy kogoś kocha album:Złote przeboje: 0
# 14 artist:Piotr Szczepanik track:Nie zabłądzisz album:Złote przeboje: 0
# 15 artist:Nosowska track:Słuchaj album:Milena: 0
# 16 artist:Nosowska track:Wo album:Milena: 0
# 17 artist:Nosowska track:Zoil album:Milena: 0
# 18 artist:Nosowska track:Nie mów (II) album:Milena: 0
# 19 artist:Justyna Steczkowska track:Świt! Świt! album:Alkimja: 1
# 20 artist:Justyna Steczkowska track:Graj, klezmerska kapelo! album:Alkimja: 1
# 21 artist:Justyna Steczkowska track:Genesis album:Alkimja: 1
# 22 artist:Justyna Steczkowska track:Ad-lo-jada album:Alkimja: 1
# 23 artist:Justyna Steczkowska track:Wszyscy braćmi być powinni album:Alkimja: 1
# 24 artist:Justyna Steczkowska track:Pieśń o Bet-lechem album:Alkimja: 1
# 25 artist:Natalia Kukulska track:Intro album:Natalia Kukulska: 0
# 26 artist:Natalia Kukulska track:I Wanna Know album:Natalia Kukulska: 0
# 27 artist:Natalia Kukulska track:Intuicja album:Natalia Kukulska: 0
# 28 artist:Natalia Kukulska track:Czekam na ciebie album:Natalia Kukulska: 0
# 29 artist:Natalia Kukulska track:Decymy album:Natalia Kukulska: 0
# 30 artist:Czesław Niemen track:Poranne Przebudzenie / Morning Awakening album:Little Wing: 0
# 31 artist:Czesław Niemen track:Little Wing album:Little Wing: 0
# 32 artist:Czesław Niemen track:Skarbona / Money-Box album:Little Wing: 0
# 33 artist:Czesław Niemen track:Wokol Step album:Rarytasy: 0
# 34 artist:Czesław Niemen track:Na Dzikich Stepach Zabajkala album:Rarytasy: 0
# 35 artist:Czesław Niemen track:Samotny Wchodze Na Droge album:Rarytasy: 0
# 36 artist:Czesław Niemen track:Osiemdziesiąty Ósmy / The Eighty Eight album:Little Wing: 0
# 37 artist:Czesław Niemen track:King album:Little Wing: 0
# 38 artist:Czesław Niemen track:Progresja Od Kciuka "Japan" / Progression From Kciuk "Japan" album:Little Wing: 0
# 39 artist:Czesław Niemen track:Dzwoneczek album:Rarytasy: 0
# 40 artist:Czesław Niemen track:Jodelki, Sosenki album:Rarytasy: 0
# 41 artist:Czesław Niemen track:Czarne Brwi, Piwne Oczy album:Rarytasy: 0
# 42 artist:Czesław Niemen track:Hej Dziewczyno Hej album:Rarytasy: 0
# 43 artist:Czesław Niemen track:Sen O Warszawie album:Rarytasy: 0
# 44 artist:Czesław Niemen track:24 Ore Spese Bone Com Amore album:Rarytasy: 0
# 45 artist:Czesław Niemen track:El Sadado De Levita album:Rarytasy: 0
# 46 artist:Czesław Niemen track:Kattorna [Zawiera: 100 Years] album:Kattorna / Pamflet Na Ludzkość: 0
# 47 artist:Czesław Niemen track:Społeczny Blues Wszechcywilizacji [Larwa (2)] album:Kattorna / Pamflet Na Ludzkość: 0
# 48 artist:Czesław Niemen track:Chłodna Ironia Przemijających Pejzaży [Marmur Biały] / Sieroctwo album:Kattorna / Pamflet Na Ludzkość: 0
# 49 artist:Czesław Niemen track:Larwa (Wers. Instrumentalna) album:Kattorna / Pamflet Na Ludzkość: 0
# 50 artist:Czesław Niemen track:Oda Do Przyrody: Moja Piosnka / Twarzą Do Słońca / Credo: Pochwała Pracy, W Prawdy Półcieniu, Burza I Kolory Tęczy album:Kattorna / Pamflet Na Ludzkość: 0
# 51 artist:Czesław Niemen track:Nie Badz Taki Bitels album:Rarytasy: 0
# 52 artist:Czesław Niemen track:Mazurek album:Rarytasy: 0
# 53 artist:Czesław Niemen track:Zapytaj album:Rarytasy: 0
# 54 artist:Czesław Niemen track:Czy Wiesz album:Rarytasy: 0
# 55 artist:Czesław Niemen track:Ach Jakie Oczy album:Rarytasy: 0
# 56 artist:Czesław Niemen track:Czy Mnie Jeszcze Pamietasz album:Rarytasy: 0
# 57 artist:Czesław Niemen track:Stoje W Oknie album:Rarytasy: 0
# 58 artist:Czesław Niemen track:Jak Mozna Wierzyc Slowom album:Rarytasy: 0
# 59 artist:Czesław Niemen track:Wiem, Ze Nie Wrocisz album:Rarytasy: 0
# 60 artist:Czesław Niemen track:Jeszcze Sen album:Rarytasy: 0
# 61 artist:Czesław Niemen track:Czas Jak Rzeka album:Rarytasy: 0
# 62 artist:Czesław Niemen track:Ptaki Spiewaja Kocham album:Rarytasy: 0
# 63 artist:Natalia Kukulska track:Witaj mi album:Śpiewa przeboje swojej mamy - Anny Jantar: 0
# 64 artist:Irena Santor track:Przeminelo Z Wiatrem album:Moje Piosenki 4: 0
# 65 artist:Irena Santor track:Przytul, Uscisnij, Pocaluj album:Moje Piosenki 4: 0
# 66 artist:Irena Santor track:Serce album:Moje Piosenki 4: 0
# 67 artist:Irena Santor track:Przy Kominku album:Moje Piosenki 4: 0
# 68 artist:Irena Santor track:Ada to Nie Wypada album:Moje Piosenki 4: 0
# 69 artist:Irena Santor track:Nie Kochac W Taka Noc album:Moje Piosenki 4: 0
# 70 artist:Irena Santor track:Przebacz album:Moje Piosenki 4: 0
# 71 artist:Maryla Rodowicz track:Dwa wesela album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 72 artist:Maryla Rodowicz track:Ja z podróży album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 73 artist:Maryla Rodowicz track:Chcę mieć syna album:Full: 0
# 74 artist:Maryla Rodowicz track:Małgośka album:Full: 0
# 75 artist:Maryla Rodowicz track:Niech żyje bal album:Full: 0
# 76 artist:Ryszard Rynkowski track:Dary losu album:Dary Losu: 1
# 77 artist:Ryszard Rynkowski track:Jestem z kamienia album:Dary Losu: 1
# 78 artist:Ryszard Rynkowski track:Nazwij to snem album:Dary Losu: 1
# 79 artist:Ryszard Rynkowski track:Widzisz Marto album:Dary Losu: 1
# 80 artist:Ryszard Rynkowski track:Zwierzenia Ryśka, czyli jedzie pociąg album:Dary Losu: 0
# 81 artist:Ryszard Rynkowski track:Życie jest nowelą album:Dary Losu: 0
# 82 artist:Ryszard Rynkowski track:Czemu nie tańczę na ulicach album:Dary Losu: 0
# 83 artist:Ryszard Rynkowski track:Szczęśliwej drogi już czas album:Dary Losu: 0
# 84 artist:Czesław Niemen track:Uns're Sommerliebe album:DT 64 Musikstudio, Volume 6: 0
# 85 artist:Edyta Bartosiewicz track:Susza album:Szok'n'Show: 0
# 86 artist:Edyta Bartosiewicz track:Szał album:Szok'n'Show: 0
# 87 artist:Edyta Bartosiewicz track:Czas przypływu album:Szok'n'Show: 0
# 88 artist:Edyta Bartosiewicz track:Ty rozumiesz album:Szok'n'Show: 0
# 89 artist:Maryla Rodowicz track:Małgośka album:Niebieska Maryla: 0
# 90 artist:Maryla Rodowicz track:Niech żyje bal album:Niebieska Maryla: 0
# 91 artist:Maryla Rodowicz track:Kasa - Sex album:Niebieska Maryla: 0
# 92 artist:Maryla Rodowicz track:Kropka nad... album:Niebieska Maryla: 0
# 93 artist:Edyta Bartosiewicz track:Angel album:Sen: 0
# 94 artist:Nosowska track:P.jer. (popieronyjerak) album:Sushi: 0
# 95 artist:Nosowska track:Weejtewelvogel album:Sushi: 0
# 96 artist:Nosowska track:Przez S album:Sushi: 0
# 97 artist:Nosowska track:Zmieniam się (wersja demo) album:Jeśli wiesz co chcę powiedzieć...: 0
# 98 artist:Ryszard Rynkowski track:Śpiewająco album:Jawa: 1
# 99 artist:Ryszard Rynkowski track:Jawa album:Jawa: 1
# 100 artist:Ryszard Rynkowski track:Kontakt album:Jawa: 1
# 101 artist:Edyta Geppert track:Punkt zwrotny album:Pamiętnik, czyli Kocham cię życie: 1
# 102 artist:Edyta Geppert track:Och życie, kocham cię nad życie album:Pamiętnik, czyli Kocham cię życie: 0
# 103 artist:Marek Grechuta track:W dzikie wino zaplątani album:Złote przeboje 1: 0
# 104 artist:Marek Grechuta track:Serce album:Złote przeboje 1: 0
# 105 artist:Marek Grechuta track:Odkąd jesteś album:Wiosna - ach to ty: 0
# 106 artist:Marek Grechuta track:Głos album:Wiosna - ach to ty: 0
# 107 artist:Marek Grechuta track:Walc karuzelowy album:Wiosna - ach to ty: 0
# 108 artist:Natalia Kukulska track:Z wyjątkiem nas (Etiuda E-dur)” album:Czułe struny: 0
# 109 artist:Natalia Kukulska track:„Ktoś całkiem nowy (Etiuda As-dur)” album:Czułe struny: 0
# 110 artist:Natalia Kukulska track:„Czułe struny (Polonez As-dur)” album:Czułe struny: 0
# 111 artist:Natalia Kukulska track:„Powiem Ci kiedy (2 Walce a-moll)" album:Czułe struny: 0
# 112 artist:Natalia Kukulska track:„Pod powieką (Preludium e-moll)” album:Czułe struny: 0
# 113 artist:Natalia Kukulska track:„Tu i teraz (Nokturn Es-dur)” album:Czułe struny: 0
# 114 artist:Stan Borys track:Pozwólcie nam żyć album:Jaskółka uwięziona: 0
# 115 artist:Stan Borys track:To wiatr ze mnie kpi album:Jaskółka uwięziona: 0
# 116 artist:Stan Borys track:Anna album:Jaskółka uwięziona: 0
# 117 artist:Stan Borys track:Spacer dziką plażą album:Jaskółka uwięziona: 0
# 118 artist:Stan Borys track:Siła kwiatów album:Jaskółka uwięziona: 0
# 119 artist:Stan Borys track:To Ziemia album:Jaskółka uwięziona: 0
# 120 artist:Natalia Kukulska track:„Znieczulenie (Preludium c-moll)” album:Czułe struny: 0
# 121 artist:Natalia Kukulska track:„Przedsionek (Koncert fortepianowy e-moll)” album:Czułe struny: 0
# 122 artist:Natalia Kukulska track:„Oda do serca (Mazurek a-moll)” album:Czułe struny: 0
# 123 artist:Natalia Kukulska track:„Zezowate szczęście (Mazurek F-dur)” album:Czułe struny: 0
# 124 artist:Natalia Kukulska track:Skończyło się album:Autoportret: 0
# 125 artist:Natalia Kukulska track:Piosenka światłoczuła album:Światło: 0
# 126 artist:Natalia Kukulska track:Sobie album:Światło: 0
# 127 artist:Natalia Kukulska track:Daleki brzeg album:Światło: 0
# 128 artist:Natalia Kukulska track:Przed wschodem słońca album:Światło: 0
# 129 artist:Natalia Kukulska track:Próg nadziei album:Światło: 0
# 130 artist:Natalia Kukulska track:Wiara czyni cuda album:Światło: 0
# 131 artist:Natalia Kukulska track:Dłoń album:Światło: 0
# 132 artist:Natalia Kukulska track:Znam cię album:Puls: 0
# 133 artist:Natalia Kukulska track:Tu mogę być sobą album:Puls: 0
# 134 artist:Natalia Kukulska track:Powieki kryją świat album:Puls: 0
# 135 artist:Ryszard Rynkowski track:Ten typ tak ma album:Ten typ tak ma: 1
# 136 artist:Krzysztof Kiljański track:Stay album:In the Room: 1
# 137 artist:Krzysztof Kiljański track:This Is Forever album:In the Room: 1
# 138 artist:Krzysztof Kiljański track:Lokator album:In the Room: 1
# 139 artist:Justyna Steczkowska track:Pejzaż bez ciebie album:Ladies: 0
# 140 artist:Maryla Rodowicz track:Bossanova do poduszki album:Ladies: 0
# 141 artist:Nosowska track:Zielono mi album:Ladies: 0
# 142 artist:Irena Santor track:Jeszcze mi wina (nalej sobie i mnie) album:Z tobą na zawsze: 0
# 143 artist:Irena Santor track:Telegram miłości album:Z tobą na zawsze: 0
# 144 artist:Irena Santor track:Jak zatrzymać tę miłość album:Z tobą na zawsze: 0
# 145 artist:Edyta Geppert track:Kwoka album:Akademia pana Kleksa: 0
# 146 artist:Maryla Rodowicz track:Osiedlowy Klub Samotnych album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 147 artist:Maryla Rodowicz track:Byłam sama, jestem sama album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 148 artist:Maryla Rodowicz track:Po naszej stronie gwiazd album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 149 artist:Maryla Rodowicz track:Katarynka album:Tribute to Agnieszka Osiecka: Łatwopalni: 0
# 150 artist:Zakopower track:Krapka soli album:Music Hal: 1
# 151 artist:Zakopower track:Siadoj z nami album:Music Hal: 1
# 152 artist:Alibabki track:Kwiat jednej nocy album:Złote przeboje: 0
# 153 artist:Alibabki track:Jak dobrze mieć sąsiada album:Złote przeboje: 0
# 154 artist:Alibabki track:Witaj rzeko album:Złote przeboje: 0
# 155 artist:Alibabki track:To ziemia album:Złote przeboje: 0
# 156 artist:Maryla Rodowicz track:Małgośka album:Złota Helena: 0
# 157 artist:Justyna Steczkowska track:Diamenty są najlepszymi przyjaciółmi dziewczyny album:Femme Fatale: 1
# 158 artist:Justyna Steczkowska track:Sex Appeal album:Femme Fatale: 1
# 159 artist:Justyna Steczkowska track:Mężczyzna ze złotym pistoletem album:Femme Fatale: 1
# 160 artist:Justyna Steczkowska track:Zadzwoń do mnie album:Femme Fatale: 1
# 161 artist:Justyna Steczkowska track:Jedna z tych kobiet album:Femme Fatale: 1
# 162 artist:Justyna Steczkowska track:Dziewczyna Szamana album:Dziewczyna Szamana: 3
# 163 artist:Justyna Steczkowska track:Czy to mi... album:Dziewczyna Szamana: 1
# 164 artist:Justyna Steczkowska track:Grawitacja album:Dziewczyna Szamana: 1
# 165 artist:Justyna Steczkowska track:Boskie Buenos (Buenos Aires) album:Dziewczyna Szamana: 1
# 166 artist:Justyna Steczkowska track:Wrogu mój album:Dziewczyna Szamana: 1
# 167 artist:Marek Grechuta track:Godzina miłowania album:The Best: 0
# 168 artist:Marek Grechuta track:Serce album:The Best: 0
# 169 artist:Marek Grechuta track:Instrumental album:The Best: 0
# 170 artist:Marek Grechuta track:Piosenka album:The Best: 0
# 171 artist:Marek Grechuta track:Dni których jeszcze nie znamy album:The Best: 0
# 172 artist:Marek Grechuta track:Nie chodź dziewczyno do miasta album:The Best: 0
# 173 artist:Ryszard Rynkowski track:Dary losu album:Intymnie: 1
# 174 artist:Ryszard Rynkowski track:Czemu nie tańczę na ulicach album:Intymnie: 1
# 175 artist:Ryszard Rynkowski track:Wszystko już było prócz nas album:Intymnie: 1
# 176 artist:Ryszard Rynkowski track:Szczęśliwej drogi już czas album:Intymnie: 1
# 177 artist:Ryszard Rynkowski track:Jawa album:Intymnie: 1
# 178 artist:Ryszard Rynkowski track:Śpiewająco album:Intymnie: 1
# 179 artist:Czesław Niemen track:Włóczęga album:Sukces: 0
# 180 artist:Stan Borys track:Anna album:The Best of: 0
# 181 artist:Stan Borys track:Wiatr od Klimczoka album:The Best of: 0
# 182 artist:Stan Borys track:To Ziemia album:The Best of: 0
# 183 artist:Stan Borys track:Spacer dziką plażą album:The Best of: 0
# 184 artist:Stan Borys track:Listów pożółkła biel album:The Best of: 0
# 185 artist:Maryla Rodowicz track:Bossanova do poduszki album:Antologia 2: 0
# 186 artist:Maryla Rodowicz track:Niech żyje bal album:Antologia 3: 0
# 187 artist:Maryla Rodowicz track:Dobranoc panowie album:Antologia 3: 0
# 188 artist:Grzegorz Markowski track:Każdej nocy album:The Best Polish Songs… Ever! Volume 2: 0
# 189 artist:Kasia Cerekwicka track:S.O.S album:The Best Polish Songs… Ever! Volume 2: 0
# 190 artist:Edyta Geppert track:Moje królestwo album:Debiut...: 0
# 191 artist:Edyta Geppert track:Debiut... album:Debiut...: 0
# 192 artist:Edyta Geppert track:Drogo prowadź album:Debiut...: 0
# 193 artist:Edyta Geppert track:Piotrusiu Panie album:Debiut...: 0
# 194 artist:Edyta Geppert track:Nie, nie żałuję album:Debiut...: 0
# 195 artist:Edyta Geppert track:Władza album:Debiut...: 0
# 196 artist:Marek Grechuta track:Lanckorona album:Złote przeboje 2: 0
# 197 artist:Czesław Niemen track:Cztery ściany świata album:Aerolit: 0
# 198 artist:Czesław Niemen track:Cztery ściany świata album:Aerolit: 0
# 199 artist:Czesław Niemen track:Cztery ściany świata album:Aerolit: 0
# 200 artist:Czesław Niemen track:Kamyk album:Aerolit: 0
# 201 artist:Czesław Niemen track:Kamyk album:Aerolit: 0
# 202 artist:Czesław Niemen track:Kamyk album:Aerolit: 0
# 203 artist:Czesław Niemen track:Mów do mnie jeszcze album:Enigmatic: 0
# 204 artist:Czesław Niemen track:Mów do mnie jeszcze album:Enigmatic: 0
# 205 artist:Czesław Niemen track:Aerumnarum plenus album:[czerwony album]: 0
# 206 artist:Czesław Niemen track:Enigmatyczne impresje album:[czerwony album]: 0
# 207 artist:Czesław Niemen track:Mój pejzaż album:[czerwony album]: 0
# 208 artist:Czesław Niemen track:Nie wyszeptuj album:spodchmurykapelusza: 0
# 209 artist:Czesław Niemen track:Sonancja album:spodchmurykapelusza: 0
# 210 artist:Czesław Niemen track:Manhattan '93 album:spodchmurykapelusza: 0
# 211 artist:Natalia Kukulska track:Cicho ciepło album:Tobie: 0
# 212 artist:Natalia Kukulska track:Byłeś jak ja album:Tobie: 0
# 213 artist:Natalia Kukulska track:Za kogo Ty się masz album:Tobie: 0
# 214 artist:Natalia Kukulska track:Zapomnieć Ciebie album:Tobie: 0
# 215 artist:Natalia Kukulska track:Kogoś przypomni album:Tobie: 0
# 216 artist:Natalia Kukulska track:Wiem gdzie to jest album:Tobie: 0
# 217 artist:Edyta Bartosiewicz track:Siedem mórz, siedem lądów album:Wodospady: 0
# 218 artist:Edyta Bartosiewicz track:Dlaczego nie mówisz nic? album:Wodospady: 0
# 219 artist:Edyta Bartosiewicz track:Sam na sam album:Wodospady: 0
# 220 artist:Edyta Bartosiewicz track:Wodospady łez album:Wodospady: 0
# 221 artist:Nosowska track:Grand Prix album:UniSexBlues: 0
# 222 artist:Marek Grechuta track:Serce album:Ocalić od zapomnienia: 0
# 223 artist:Marek Grechuta track:W malinowym chruśniaku album:Ocalić od zapomnienia: 0
# 224 artist:Marek Grechuta track:Głos album:Ocalić od zapomnienia: 0
# 225 artist:Marek Grechuta track:Miłość drogę zna album:Ocalić od zapomnienia: 0
# 226 artist:Marek Grechuta track:Tajemniczy uśmiech album:Ocalić od zapomnienia: 0
# 227 artist:Marek Grechuta track:Takiej miłości nam życzę album:Ocalić od zapomnienia: 0
# 228 artist:Marek Grechuta track:Królowie, królowie album:Pieśni Marka Grechuty do słów Tadeusza Nowaka: 0
# 229 artist:Marek Grechuta track:Super ekspres album:Pieśni Marka Grechuty do słów Tadeusza Nowaka: 0
# 230 artist:Marek Grechuta track:Głos album:Pieśni Marka Grechuty do słów Tadeusza Nowaka: 0
# 231 artist:Marek Grechuta track:Gdzie mieszkasz nocy album:Pieśni Marka Grechuty do słów Tadeusza Nowaka: 0
# 232 artist:Maryla Rodowicz track:Małgośka album:Przed zakrętem: 0
# 233 artist:Maryla Rodowicz track:Opera mydlana album:Przed zakrętem: 0
# 234 artist:Maryla Rodowicz track:Seledynowa lampka album:Przed zakrętem: 0
# 235 artist:Maryla Rodowicz track:Moja Europo album:Przed zakrętem: 0
# 236 artist:Maryla Rodowicz track:Co się stało z mamą? album:Przed zakrętem: 0
# 237 artist:Maryla Rodowicz track:Czy warto album:Przed zakrętem: 0
# 238 artist:Maryla Rodowicz track:Trzy, może nawet cztery dni album:Platynowa kolekcja: Złote przeboje: 0
# 239 artist:Maryla Rodowicz track:azja (hooray! hooray! it;s a holi-holiday) album:Karnawał 2000: 0
# 240 artist:Maryla Rodowicz track:Kasa - Sex album:Naj-wieksze przeboje: 0
# 241 artist:Maryla Rodowicz track:Zaśnij duszko album:Życie ładna rzecz: 0
# 242 artist:Maryla Rodowicz track:Daj mi byle co album:Kochać: 1
# 243 artist:Maryla Rodowicz track:Nie ma cię... bardziej niż zwykle album:Kochać: 1
# 244 artist:Maryla Rodowicz track:U mnie już noc album:Kochać: 1
# 245 artist:Maryla Rodowicz track:Małgośka album:Damą być: 0
# 246 artist:Maryla Rodowicz track:Bossanova do poduszki album:Damą być: 0
# 247 artist:Maryla Rodowicz track:Niech żyje bal album:Damą być: 0
# 248 artist:Maryla Rodowicz track:To juz bylo album:Absolutnie nic: 1
# 249 artist:Maryla Rodowicz track:Czlowiek, czlowiek album:Absolutnie nic: 0
# 250 artist:Maryla Rodowicz track:Tak naprawde nie dzieje sie nic album:Absolutnie nic: 1
# 251 artist:Maryla Rodowicz track:Hej sokoLy album:Marysia Biesiadna: 0
# 252 artist:Maryla Rodowicz track:Jak dobrze nam zdobywac góry album:Marysia Biesiadna: 0
# 253 artist:Maryla Rodowicz track:Kolibaj sie, kolibaj album:Marysia Biesiadna: 0
# 254 artist:Maryla Rodowicz track:Idzie noc album:Marysia Biesiadna: 0
# 255 artist:Maryla Rodowicz track:I co, i co album:Złota Maryla: 0
# 256 artist:Maryla Rodowicz track:Idioci album:Złota Maryla: 0
# 257 artist:Maryla Rodowicz track:Z sufitu album:Złota Maryla: 0
# 258 artist:Maryla Rodowicz track:Chcę mieć syna album:Antologia 1: 0
# 259 artist:Maryla Rodowicz track:Trzy, może nawet cztery dni album:Antologia 1: 0
# 260 artist:Maryla Rodowicz track:Ludzie, kocham Was album:Antologia 1: 0
# 261 artist:Maryla Rodowicz track:Z Tobą w górach album:Antologia 1: 0
# 262 artist:Maryla Rodowicz track:Małgośka album:Antologia 1: 0
# 263 artist:Maryla Rodowicz track:Powołanie album:Antologia 1: 0
# 264 artist:Maryla Rodowicz track:Wio koniku album:Antologia 1: 0
# 265 artist:Seweryn Krajewski track:Och, Karol album:Piosenki Filmowe: 0
# 266 artist:Seweryn Krajewski track:Roma album:Piosenki Filmowe: 0
# 267 artist:Seweryn Krajewski track:Galimatias album:Piosenki Filmowe: 0
# 268 artist:Edyta Bartosiewicz track:XXI wiek album:Dziś są moje urodziny: 0
# 269 artist:Edyta Bartosiewicz track:Skłamałam album:Dziś są moje urodziny: 0
# 270 artist:Edyta Bartosiewicz track:Szał album:Dziś są moje urodziny: 0
# 271 artist:Edyta Bartosiewicz track:Siedem mórz, siedem lądów album:Dziś są moje urodziny: 0
# 272 artist:Marek Grechuta track:Miłość drogę zna album:Krajobraz pełen nadziei: 0
# 273 artist:Marek Grechuta track:Takiej miłości nam życzę album:Krajobraz pełen nadziei: 0
# 274 artist:Marek Grechuta track:Tajemniczy uśmiech album:Krajobraz pełen nadziei: 0
# 275 artist:Marek Grechuta track:Miłość drogę zna album:Krajobraz pełen nadziei: 0
# 276 artist:Marek Grechuta track:Takiej miłości nam życzę album:Krajobraz pełen nadziei: 0
# 277 artist:Marek Grechuta track:Tajemniczy uśmiech album:Krajobraz pełen nadziei: 0
# 278 artist:Maryla Rodowicz track:Dzisiaj W Betlejem album:Kolędy: 0
# 279 artist:Maryla Rodowicz track:Przybieżeli Do Betlejem album:Kolędy: 0
# 280 artist:Maryla Rodowicz track:Gdy Śliczna Panna album:Kolędy: 0
# 281 artist:Maryla Rodowicz track:Cicha Noc album:Kolędy: 0
# 282 artist:Maryla Rodowicz track:W Żłobie Leży album:Kolędy: 0
# 283 artist:Maryla Rodowicz track:Pójdźmy Wszyscy Do Stajenki album:Kolędy: 0
# 284 artist:Czesław Niemen track:Aerumnarum plenus album:Człowiek jam niewdzięczny: 0
# 285 artist:Czesław Niemen track:Enigmatyczne impresje album:Człowiek jam niewdzięczny: 0
# 286 artist:Czesław Niemen track:Mój pejzaż album:Człowiek jam niewdzięczny: 0
# 287 artist:Czesław Niemen track:Piosenka dla zmarłej album:Marionetki: 0
# 288 artist:Czesław Niemen track:Ptaszek album:Marionetki: 0
# 289 artist:Czesław Niemen track:Com uczynił album:Marionetki: 0
# 290 artist:Seweryn Krajewski track:Przestał padać deszcz album:Opowieści muzyczne, Volume 1: Lubię ten smutek: 0
# 291 artist:Seweryn Krajewski track:Wołaj mnie album:Opowieści muzyczne, Volume 1: Lubię ten smutek: 0
# 292 artist:Seweryn Krajewski track:Dom album:Opowieści muzyczne, Volume 1: Lubię ten smutek: 0
# 293 artist:Seweryn Krajewski track:Przytul mnie mocno album:Opowieści muzyczne, Volume 1: Lubię ten smutek: 0
# 294 artist:Czesław Niemen track:Pokój album:Postscriptum: 0
# 295 artist:Czesław Niemen track:Moje zapatrzenie album:Postscriptum: 0
# 296 artist:Czesław Niemen track:Ty pajdi maja karawuszka damoj album:Russische Lieder: 0
# 297 artist:Czesław Niemen track:Kalabielnaja album:Russische Lieder: 0
# 298 artist:Czesław Niemen track:Razkinulos morie szyroko album:Russische Lieder: 0
# 299 artist:Seweryn Krajewski track:Baw mnie album:Przemija uroda w nas: 0
# 300 artist:Stan Borys track:Idę drogą nieznaną album:Idę drogą nieznaną: 0
# 301 artist:Stan Borys track:To ziemia album:Idę drogą nieznaną: 0
# 302 artist:Stan Borys track:Spacer dziką plażą album:Idę drogą nieznaną: 0
# 303 artist:Stan Borys track:Wiatr od Klimczoka album:Idę drogą nieznaną: 0
# 304 artist:Stan Borys track:Listów pożółkła biel album:Idę drogą nieznaną: 0
# 305 artist:Stan Borys track:Szukam przyjaciela album:Idę drogą nieznaną: 0
# 306 artist:Stan Borys track:Chcę przy tym być album:Idę drogą nieznaną: 0
# 307 artist:Natalia Kukulska track:Piosenka światłoczuła album:Muzyczne Lato: 0
# 308 artist:Justyna Steczkowska track:A mogło być album:Flota zjednoczonych sił: 0
# 309 artist:Alibabki track:Dojeżdżam album:Pożegnanie Poetki - Piosenki Agnieszki Osieckiej: 0
# 310 artist:Alibabki track:Śpiewam bo muszę album:Pożegnanie Poetki - Piosenki Agnieszki Osieckiej: 0
# 311 artist:Marek Grechuta track:W dzikie wino zaplątani album:Płytoteka Dziennika: Poeci Piosenki: 0
# 312 artist:Alibabki track:Kwiat jednej nocy album:Płytoteka Dziennika: Poeci Piosenki: Jonasz Kofta: 0
# 313 artist:Czesław Niemen track:Mój pejzaż album:Czesław Niemen: 0
# 314 artist:Czesław Niemen track:El Soldado album:Sen o Warszawie: 0
# 315 artist:Czesław Niemen track:Ptaki śpiewają - kocham album:Sen o Warszawie: 0
# 316 artist:Czesław Niemen track:Stoję w oknie album:Sen o Warszawie: 0
# 317 artist:Marek Grechuta track:Mieć taki deszcz, gdy świeci słońce album:Śpiewające obrazy: 0
# 318 artist:Marek Grechuta track:Tajemniczy uśmiech (Gioconda) album:Śpiewające obrazy: 0
# 319 artist:Marek Grechuta track:Tancerka z bukietem album:Śpiewające obrazy: 0
# 320 artist:Marek Grechuta track:Śniadanie na trawie album:Śpiewające obrazy: 0
# 321 artist:Marek Grechuta track:Władza album:Dziesięć ważnych słów: 0
# 322 artist:Marek Grechuta track:Natura album:Dziesięć ważnych słów: 0
# 323 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Dziesięć ważnych słów: 0
# 324 artist:Marek Grechuta track:Gdziekolwiek album:Dziesięć ważnych słów: 0
# 325 artist:Marek Grechuta track:Niebieski młyn album:Korowód: 1
# 326 artist:Marek Grechuta track:Letnia przygoda album:Korowód: 0
# 327 artist:Marek Grechuta track:Nie chodź dziewczyno do miasta album:Korowód: 0
# 328 artist:Marek Grechuta track:Piosenka album:Korowód: 0
# 329 artist:Marek Grechuta track:Taniec na dworze Hektora album:Krajobraz pełen nadziei: 0
# 330 artist:Marek Grechuta track:Wenecja album:Krajobraz pełen nadziei: 0
# 331 artist:Marek Grechuta track:Lanckorona album:Krajobraz pełen nadziei: 0
# 332 artist:Marek Grechuta track:W malinowym chruśniaku album:W malinowym chruśniaku: 0
# 333 artist:Marek Grechuta track:Czasami mojej ślepej posłuszny ochocie album:W malinowym chruśniaku: 0
# 334 artist:Marek Grechuta track:Ty pierwej mgły dosięgasz album:W malinowym chruśniaku: 0
# 335 artist:Marek Grechuta track:Ani zmora z jeziora, ani sen skrzydlaty album:W malinowym chruśniaku: 0
# 336 artist:Marek Grechuta track:Nie zapomnisz tej mojej tęsknoty album:W malinowym chruśniaku: 0
# 337 artist:Marek Grechuta track:Mów do mnie jeszcze album:W malinowym chruśniaku: 0
# 338 artist:Marek Grechuta track:Śmierci, która uczysz człowieka album:W malinowym chruśniaku: 0
# 339 artist:Marek Grechuta track:Polowanie na muchy album:W malinowym chruśniaku: 0
# 340 artist:Marek Grechuta track:Jadę pociągiem prawdziwym album:Piosenki dla dzieci i rodziców: 0
# 341 artist:Marek Grechuta track:Czy to pies, czy to bies album:Piosenki dla dzieci i rodziców: 0
# 342 artist:Marek Grechuta track:Płynie, płynie woda album:Piosenki dla dzieci i rodziców: 0
# 343 artist:Marek Grechuta track:Pajac Teofil album:Piosenki dla dzieci i rodziców: 0
# 344 artist:Marek Grechuta track:Jadę pociągiem prawdziwym album:Piosenki dla dzieci i rodziców: 0
# 345 artist:Marek Grechuta track:Super ekspres album:Piosenki dla dzieci i rodziców: 0
# 346 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Godzina miłowania: 0
# 347 artist:Marek Grechuta track:Serce album:Godzina miłowania: 0
# 348 artist:Marek Grechuta track:Tajemniczy uśmiech (Gioconda) album:Godzina miłowania: 0
# 349 artist:Marek Grechuta track:W dzikie wino zaplątani album:Godzina miłowania: 0
# 350 artist:Marek Grechuta track:Godzina miłowania album:Godzina miłowania: 0
# 351 artist:Justyna Steczkowska track:To tylko złudzenie (to nie miłość) album:Daj mi chwilę: 2
# 352 artist:Justyna Steczkowska track:W przód i w tył album:Daj mi chwilę: 2
# 353 artist:Justyna Steczkowska track:Białe pola album:Daj mi chwilę: 2
# 354 artist:Justyna Steczkowska track:Twój aniołek stróż album:Puchowe kołysanki: 1
# 355 artist:Justyna Steczkowska track:Schowaj noc pod koc album:Puchowe kołysanki: 0
# 356 artist:Piotr Szczepanik track:Goniąc Kormorany album:Złote przeboje: 0
# 357 artist:Piotr Szczepanik track:Puste Koperty album:Złote przeboje: 0
# 358 artist:Piotr Szczepanik track:Żółte Kalendarze album:Złote przeboje: 0
# 359 artist:Piotr Szczepanik track:Zabawa Podmiejska album:Złote przeboje: 0
# 360 artist:Marek Grechuta track:Widzieć więcej album:Korowód: 1
# 361 artist:Marek Grechuta track:Kantata album:Korowód: 1
# 362 artist:Marek Grechuta track:Chodźmy album:Korowód: 1
# 363 artist:Marek Grechuta track:Świecie nasz album:Korowód: 1
# 364 artist:Marek Grechuta track:Nowy radosny dzień album:Korowód: 1
# 365 artist:Marek Grechuta track:Dni, których nie znamy album:Korowód: 1
# 366 artist:Marek Grechuta track:Korowód album:Korowód: 1
# 367 artist:Marek Grechuta track:Niebieski młyn album:Korowód: 1
# 368 artist:Marek Grechuta track:W dzikie wino zaplątani album:Ocalić od zapomnienia: 0
# 369 artist:Marek Grechuta track:Niebieski młyn album:Ocalić od zapomnienia: 0
# 370 artist:Marek Grechuta track:Piosenka album:Ocalić od zapomnienia: 0
# 371 artist:Marek Grechuta track:Serce album:Ocalić od zapomnienia: 0
# 372 artist:Marek Grechuta track:Gdziekolwiek album:Ocalić od zapomnienia: 0
# 373 artist:Natalia Kukulska track:In Silence album:Sexi Flexi: 1
# 374 artist:Czesław Niemen track:Niemen zza Buga album:Miło wspomnieć: 0
# 375 artist:Czesław Niemen track:El Soldado album:Miło wspomnieć: 0
# 376 artist:Czesław Niemen track:Moje piosenki album:Miło wspomnieć: 0
# 377 artist:Czesław Niemen track:Prze Monachium do Ameryki album:Miło wspomnieć: 0
# 378 artist:Czesław Niemen track:Niemen Od Początku album:Miło wspomnieć: 0
# 379 artist:Czesław Niemen track:Mów do mnie jeszcze album:Miło wspomnieć: 0
# 380 artist:Marek Grechuta track:Serce album:Złota Kolekcja: Dni, których nie znamy: 0
# 381 artist:Marek Grechuta track:Gdziekolwiek album:Złota Kolekcja: Dni, których nie znamy: 0
# 382 artist:Marek Grechuta track:W dzikie wino zaplątani album:Złota Kolekcja: Dni, których nie znamy: 0
# 383 artist:Marek Grechuta track:W malinowym chruśniaku album:Złota Kolekcja: Dni, których nie znamy: 0
# 384 artist:K.A.S.A. track:Maczo album:Maczo: 4
# 385 artist:K.A.S.A. track:Maczo Latino album:Maczo: 0
# 386 artist:K.A.S.A. track:Reklama 2000 album:Maczo: 0
# 387 artist:Czesław Niemen track:Dorożką na księżyc album:Katharsis: 0
# 388 artist:Czesław Niemen track:Dorożką na księżyc album:Katharsis: 0
# 389 artist:Czesław Niemen track:Fatum album:Katharsis: 0
# 390 artist:Czesław Niemen track:Fatum album:Katharsis: 0
# 391 artist:Czesław Niemen track:Pieczęć album:Katharsis: 0
# 392 artist:Czesław Niemen track:Pieczęć album:Katharsis: 0
# 393 artist:Czesław Niemen track:Katharsis album:Katharsis: 0
# 394 artist:Czesław Niemen track:Katharsis album:Katharsis: 0
# 395 artist:K.A.S.A. track:Trendy album:Wszystko od nowa: 0
# 396 artist:K.A.S.A. track:Fajne fanki album:Wszystko od nowa: 0
# 397 artist:Seweryn Krajewski track:Dom Agaty album:Uprowadzenie Agaty: 0
# 398 artist:Seweryn Krajewski track:Ważne spotkanie album:Uprowadzenie Agaty: 0
# 399 artist:Seweryn Krajewski track:Opowieść o Cyganie album:Uprowadzenie Agaty: 0
# 400 artist:Seweryn Krajewski track:Samotność Agaty album:Uprowadzenie Agaty: 0
# 401 artist:Seweryn Krajewski track:Taka Ameryka album:Uprowadzenie Agaty: 0
# 402 artist:Seweryn Krajewski track:Obława album:Uprowadzenie Agaty: 0
# 403 artist:Piotr Szczepanik track:Żółte kalendarze album:Gold Edition: 0
# 404 artist:Piotr Szczepanik track:Każdy kogoś kocha album:Gold Edition: 0
# 405 artist:Piotr Szczepanik track:Nie zabłądzisz album:Gold Edition: 0
# 406 artist:Piotr Szczepanik track:Niedomówienie album:Gold Edition: 0
# 407 artist:Piotr Szczepanik track:Zanim zaśniesz album:Gold Edition: 0
# 408 artist:Edyta Geppert track:Jaka róża taki cierń album:Audiobiografia: 0
# 409 artist:Maryla Rodowicz track:Byłam sama, jestem sama album:Wsiąść do pociągu: 1
# 410 artist:Maryla Rodowicz track:Mały barek w Santa Cruz album:Wsiąść do pociągu: 1
# 411 artist:Maryla Rodowicz track:Chcę mieć syna album:Żyj mój świecie: 1
# 412 artist:Maryla Rodowicz track:Dwa wesela album:Rok: 1
# 413 artist:Justyna Steczkowska track:Dziewczyna szamana album:The Best Polish Songs… Ever!: 0
# 414 artist:K.A.S.A. track:Ten cały cyrk album:nEUROmantic: 1
# 415 artist:K.A.S.A. track:Nie przestawaj... album:nEUROmantic: 1
# 416 artist:K.A.S.A. track:Każdy chce być didżejem album:nEUROmantic: 1
# 417 artist:Kasia Cerekwicka track:Intro album:Pokój 203: 1
# 418 artist:Kasia Cerekwicka track:Kameleon album:Pokój 203: 1
# 419 artist:Kasia Cerekwicka track:Nie potrzebuję ciebie album:Pokój 203: 1
# 420 artist:Kasia Cerekwicka track:Sekret album:Pokój 203: 1
# 421 artist:Nosowska track:WeejteWelVogel album:Tfu: 0
# 422 artist:Krzysztof Kiljański track:Dzień pomyłek album:Yugopolis 2: 0
# 423 artist:Krzysztof Kiljański track:Dla siebie sami album:Yugopolis 2: 0
# 424 artist:Maryla Rodowicz track:To juz bylo album:Niebieska Maryla: 0
# 425 artist:Maryla Rodowicz track:Do lezki lezka album:Niebieska Maryla: 0
# 426 artist:Maryla Rodowicz track:Kasa Sex album:Niebieska Maryla: 0
# 427 artist:Ryszard Rynkowski track:Wsrod nocnej ciszy album:Koledy z Gwiazdami: 0
# 428 artist:Marek Grechuta track:Gdziekolwiek album:Jeszcze pożyjemy: 0
# 429 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Jeszcze pożyjemy: 0
# 430 artist:Marek Grechuta track:A więc to nie tak album:Jeszcze pożyjemy: 0
# 431 artist:Marek Grechuta track:Godzina miłowania album:Jeszcze pożyjemy: 0
# 432 artist:Marek Grechuta track:Piosenka album:Jeszcze pożyjemy: 0
# 433 artist:Marek Grechuta track:Instrumental album:Unikaty: 0
# 434 artist:Marek Grechuta track:Motorek album:Unikaty: 0
# 435 artist:Marek Grechuta track:Marecelle Lender tańcząca Bolero - Toulouse-Lautrec album:Unikaty: 0
# 436 artist:Marek Grechuta track:Inna kuchnia, inna moda - Manet - Śniadanie na trawie album:Unikaty: 0
# 437 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Unikaty: 0
# 438 artist:Marek Grechuta track:Nad zrębem planety album:Unikaty: 0
# 439 artist:Marek Grechuta track:Oto ja - oto on album:Unikaty: 0
# 440 artist:Marek Grechuta track:Motorek album:Unikaty: 0
# 441 artist:Marek Grechuta track:Ostania stacja rezygnacja album:Unikaty: 0
# 442 artist:Marek Grechuta track:Pomnę jak niegdyś album:Unikaty: 0
# 443 artist:Marek Grechuta track:Godzina miłowania album:Unikaty: 0
# 444 artist:Edyta Geppert track:Opuszczona album:Śpiewam życie: 1
# 445 artist:Edyta Geppert track:Wyjaśnienie album:Śpiewam życie: 1
# 446 artist:Edyta Geppert track:Meshuge album:Śpiewam życie: 1
# 447 artist:Edyta Geppert track:Władza album:Śpiewam życie: 1
# 448 artist:Edyta Geppert track:Do trzeciej z cnót album:Nic nie muszę: 0
# 449 artist:Edyta Geppert track:Szukaj mnie album:Nic nie muszę: 0
# 450 artist:Edyta Geppert track:Sentymentu mgła album:Nic nie muszę: 0
# 451 artist:Edyta Geppert track:Zapowiedź - Edyta Geppert album:Nic nie muszę: 0
# 452 artist:Marek Grechuta track:Świecie nasz album:Korowód: 1
# 453 artist:Marek Grechuta track:Nowy radosny dzień album:Korowód: 1
# 454 artist:Marek Grechuta track:Dni, których nie znamy album:Korowód: 1
# 455 artist:Marek Grechuta track:Korowód album:Korowód: 1
# 456 artist:Marek Grechuta track:Niebieski młyn album:Korowód: 1
# 457 artist:Marek Grechuta track:Widzieć więcej - Introdukcja album:Korowód: 0
# 458 artist:Marek Grechuta track:Kantata album:Korowód: 1
# 459 artist:Marek Grechuta track:Chodźmy album:Korowód: 1
# 460 artist:Czesław Niemen track:Nie Wstawaj Lewą Nogą album:Największe przeboje: 0
# 461 artist:Czesław Niemen track:Domek bez adresu album:Największe przeboje: 0
# 462 artist:Czesław Niemen track:Włóczęga album:Największe przeboje: 0
# 463 artist:Czesław Niemen track:Spiżowy krzyk album:Największe przeboje: 0
# 464 artist:Czesław Niemen track:Bema pamięci żalobny rapsod album:Największe przeboje: 0
# 465 artist:Edyta Geppert track:Pijmy album:Śpiewajmy: 0
# 466 artist:Edyta Geppert track:Ballada album:Śpiewajmy: 0
# 467 artist:Edyta Geppert track:Opuszczona album:Śpiewajmy: 0
# 468 artist:Edyta Geppert track:Wyjaśnienie album:Śpiewajmy: 0
# 469 artist:Edyta Geppert track:Jestem, więc myślę album:Śpiewajmy: 0
# 470 artist:Czesław Niemen track:Jeszcze swój egzamin zdasz album:Gold Edition: 0
# 471 artist:Czesław Niemen track:Jaki kolor wybrać chcesz album:Gold Edition: 0
# 472 artist:Czesław Niemen track:Domek bez adresu album:Gold Edition: 0
# 473 artist:Czesław Niemen track:Włóczęga album:Gold Edition: 0
# 474 artist:Marek Grechuta track:Gdziekolwiek album:Droga za widnokres: 1
# 475 artist:Marek Grechuta track:Natura album:Dziesięć ważnych słów: 0
# 476 artist:Marek Grechuta track:Piosenka album:40 piosenek: 1
# 477 artist:Marek Grechuta track:Gdziekolwiek album:40 piosenek: 1
# 478 artist:Marek Grechuta track:Godzina miłowania album:40 piosenek: 1
# 479 artist:Marek Grechuta track:W dzikie wino zaplątani album:Aż 10 największych przebojów: 0
# 480 artist:Marek Grechuta track:Serce album:Złota Kolekcja: Dni, których nie znamy: 0
# 481 artist:Marek Grechuta track:Gdziekolwiek album:Złota Kolekcja: Dni, których nie znamy: 0
# 482 artist:Marek Grechuta track:W dzikie wino zaplątani album:Złota Kolekcja: Dni, których nie znamy: 0
# 483 artist:Marek Grechuta track:W malinowym chruśniaku album:Złota Kolekcja: Dni, których nie znamy: 0
# 484 artist:Marek Grechuta track:Pomarańcze, mandarynki album:Złota Kolekcja: Dni, których nie znamy: 0
# 485 artist:Marek Grechuta track:Krajobraz z Wilgą i ludzie album:Droga za widnokres: 1
# 486 artist:Marek Grechuta track:Gdziekolwiek album:Droga za widnokres: 1
# 487 artist:Marek Grechuta track:Miłość drogę zna album:Złota kolekcja: Gdzieś w nas: 0
# 488 artist:Marek Grechuta track:Motorek album:Złota kolekcja: Gdzieś w nas: 0
# 489 artist:Marek Grechuta track:Głos album:Złota kolekcja: Gdzieś w nas: 0
# 490 artist:Marek Grechuta track:Odkąd jesteś album:Złota kolekcja: Gdzieś w nas: 0
# 491 artist:Marek Grechuta track:Lanckorona album:Złota kolekcja: Gdzieś w nas: 0
# 492 artist:Marek Grechuta track:Tajemniczy uśmiech album:Złota kolekcja: Gdzieś w nas: 0
# 493 artist:Marek Grechuta track:Gdziekolwiek album:Gold Edition: 0
# 494 artist:Marek Grechuta track:Krajobraz z Wilgą i ludzie album:Gold Edition: 0
# 495 artist:Marek Grechuta track:Władza album:Dziesięć ważnych słów: 0
# 496 artist:Marek Grechuta track:Serce album:40 piosenek: 1
# 497 artist:Marek Grechuta track:W dzikie wino zaplątani album:40 piosenek: 1
# 498 artist:Marek Grechuta track:Niebieski młyn album:Gold Edition: 0
# 499 artist:Marek Grechuta track:Serce album:Gold Edition: 0
# 500 artist:Marek Grechuta track:W dzikie wino zaplątani album:Gold Edition: 0
# 501 artist:Marek Grechuta track:Gdziekolwiek album:Korowód: 0
# 502 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Korowód: 0
# 503 artist:Marek Grechuta track:Znajdziemy siebie album:Korowód: 0
# 504 artist:Marek Grechuta track:A więc to nie tak album:Magia obłoków: 0
# 505 artist:Marek Grechuta track:W dzikie wino zaplątani album:Marek Grechuta & Anawa: 2
# 506 artist:Marek Grechuta track:Piosenka album:Marek Grechuta & Anawa: 1
# 507 artist:Marek Grechuta track:Serce album:Marek Grechuta & Anawa: 2
# 508 artist:Marek Grechuta track:Niebieski młyn album:Marek Grechuta & Anawa: 0
# 509 artist:Marek Grechuta track:Serce album:Ocalić od zapomnienia: 0
# 510 artist:Marek Grechuta track:Niebieski młyn album:40 piosenek: 1
# 511 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:40 piosenek: 1
# 512 artist:Marek Grechuta track:A więc to nie tak album:40 piosenek: 0
# 513 artist:Marek Grechuta track:Miłość drogę zna album:40 piosenek: 1
# 514 artist:Marek Grechuta track:Takiej miłości nam życzę album:40 piosenek: 1
# 515 artist:Marek Grechuta track:Tajemniczy uśmiech album:40 piosenek: 1
# 516 artist:Marek Grechuta track:Widok z balkonu (Lanckorona) album:Niezwykłe miejsca: 0
# 517 artist:Marek Grechuta track:Jakby wypłynął nagle (Opera w Sydney) album:Niezwykłe miejsca: 0
# 518 artist:Marek Grechuta track:Moje miasto Kraków (Kraków) album:Niezwykłe miejsca: 0
# 519 artist:Piotr Szczepanik track:Żółte kalendarze album:40 przebojów na 40-lecie Trójki: 0
# 520 artist:Maryla Rodowicz track:Małgośka album:40 przebojów na 40-lecie Trójki: 0
# 521 artist:Justyna Steczkowska track:Dziewczyna Szamana album:40 przebojów na 40-lecie Trójki: 0
# 522 artist:Marek Grechuta track:Królowie, królowie album:Pieśni Marka Grechuty do słów Tadeusza Nowaka: 0
# 523 artist:Marek Grechuta track:Niech będzie imię Twe błogosławione album:Słowa - Wiersze Karola Wojtyły: 0
# 524 artist:Nosowska track:Hello album:Unhappy Songs: 0
# 525 artist:Justyna Steczkowska track:Dziewczyna Szamana album:Złote przeboje polskiej piosenki: lata 90.: 0
# 526 artist:Maryla Rodowicz track:Ja z podróży album:Ocean popielaty: 0
# 527 artist:Marek Grechuta track:Odkąd jesteś album:Niezwykłe miejsca: 0
# 528 artist:Marek Grechuta track:Głos album:Niezwykłe miejsca: 0
# 529 artist:Marek Grechuta track:Tajemniczy uśmiech (Gioconda) album:Niezwykłe miejsca: 0
# 530 artist:Marek Grechuta track:Jakby wypłynął nagle (Opera w Sydney) album:Niezwykłe miejsca: 0
# 531 artist:Czesław Niemen track:Spiżowy krzyk album:Spiżowy krzyk: 0
# 532 artist:Czesław Niemen track:Cztery ściany świata album:Spiżowy krzyk: 0
# 533 artist:Czesław Niemen track:Ptaszek album:Spiżowy krzyk: 0
# 534 artist:Czesław Niemen track:Moje zapatrzenie album:Spiżowy krzyk: 0
# 535 artist:Czesław Niemen track:Status mojego ja album:Spiżowy krzyk: 0
# 536 artist:Edyta Bartosiewicz track:Skłamałam album:Golden NAJ 007: 0
# 537 artist:Stan Borys track:Szukam przyjaciela album:Polish Funk, Volume 3: The Unique Selection of Rare Grooves From Poland of the 70's: 0
# 538 artist:Marek Grechuta track:W dzikie wino zaplątani album:Marek Grechuta & Anawa: 2
# 539 artist:Marek Grechuta track:Piosenka album:Marek Grechuta & Anawa: 1
# 540 artist:Marek Grechuta track:Serce album:Marek Grechuta & Anawa: 2
# 541 artist:Marek Grechuta track:Nie chodź dziewczyno do miasta album:Marek Grechuta & Anawa: 0
# 542 artist:Marek Grechuta track:W dzikie wino zaplątani album:Marek Grechuta & Anawa: 2
# 543 artist:Marek Grechuta track:Gdy zabrakło ci uśmiechu album:Marek Grechuta & Anawa: 0
# 544 artist:Czesław Niemen track:Stoję w oknie album:Czas jak rzeka: 0
# 545 artist:Czesław Niemen track:Obok nas album:Czas jak rzeka: 0
# 546 artist:Czesław Niemen track:Pokój album:Czas jak rzeka: 0
# 547 artist:Krzysztof Kiljański track:Prócz Ciebie, nic (feat. Kayah) album:Magda M - Piosenki nie tylko o miłości: 0
# 548 artist:Marek Grechuta track:A więc to nie tak album:Magia obłoków: 0
# 549 artist:Marek Grechuta track:Godzina miłowania album:Magia obłoków: 0
# 550 artist:Marek Grechuta track:Znajdziemy siebie album:Magia obłoków: 0
# 551 artist:Marek Grechuta track:Suita 'Spotkania w czasie' album:Magia obłoków: 0
# 552 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Magia obłoków: 0
# 553 artist:Marek Grechuta track:Gdziekolwiek album:Magia obłoków: 0
# 554 artist:Marek Grechuta track:Godzina miłowania album:Magia obłoków: 0
# 555 artist:Justyna Steczkowska track:To Mój Czas album:To mój czas: 1
# 556 artist:Justyna Steczkowska track:Tango album:To mój czas: 1
# 557 artist:Justyna Steczkowska track:One album:To mój czas: 1
# 558 artist:Nosowska track:Pa album:8: 1
# 559 artist:Nosowska track:JPS album:8: 1
# 560 artist:Krzysztof Kiljański track:Pamiętasz Była Jesień album:Cudowny Świat: 0
# 561 artist:Małgorzata Kożuchowska track:Samba przed Rozstaniem album:Cudowny Świat: 0
# 562 artist:Małgorzata Kożuchowska track:What a Wonderful World album:Cudowny Świat: 0
# 564 artist:Maryla Rodowicz track:Niech żyje bal album:Pięć Oceanów: 0
# 565 artist:Maryla Rodowicz track:Ja z podróży album:Pięć Oceanów: 0
# 566 artist:Seweryn Krajewski track:Jakżes niestała album:Pięć Oceanów: 0
# 567 artist:Maryla Rodowicz track:Małgośka album:Pięć Oceanów: 0
# 568 artist:Marek Grechuta track:Jadę pociągiem prawdziwym album:Piosenki dla dzieci i rodziców: 0
# 569 artist:Marek Grechuta track:Nad zrębem planety album:Szalona lokomotywa: 0
# 570 artist:Marek Grechuta track:Oto ja - oto on album:Szalona lokomotywa: 0
# 571 artist:Marek Grechuta track:Motorek album:Szalona lokomotywa: 0
# 572 artist:Marek Grechuta track:Pomnę jak niegdyś album:Szalona lokomotywa: 0
# 573 artist:Marek Grechuta track:Czy to tu? album:Szalona lokomotywa: 0
# 574 artist:Marek Grechuta track:Taniec szewców album:Szalona lokomotywa: 0
# 575 artist:Maryla Rodowicz track:Weź mnie ze sobą album:Szalona lokomotywa: 0
# 576 artist:Maryla Rodowicz track:Pieśń miłości album:Buty 2: 0
# 577 artist:Maryla Rodowicz track:Źródło Jan album:Buty 2: 0
# 578 artist:Maryla Rodowicz track:Nadzieja album:Buty 2: 0
# 579 artist:Maryla Rodowicz track:Więc kto album:Buty 2: 0
# 580 artist:Maryla Rodowicz track:Tonę album:Buty 2: 0
# 581 artist:Marek Grechuta track:Piosenka album:Polski Top Wszech Czasów vol. 2: 0
# 582 artist:Alibabki track:Kapitańskie tango album:Wideoteka Dorosłego Człowieka - Część 1 - Nasze piosenki: 0
# 583 artist:Ryszard Rynkowski track:Szczęśliwej drogi już czas album:Wideoteka Dorosłego Człowieka - Część 1 - Nasze piosenki: 0
# 584 artist:Irena Santor track:Serce album:Duety: 0
# 585 artist:Justyna Steczkowska track:Ej, przeleciał ptaszek album:Duety: 0
# 587 artist:Irena Santor track:Irena Santor album:Duety: 0
# 588 artist:Justyna Steczkowska track:Oko za oko album:Wznieś serce: 0
# 589 artist:Justyna Steczkowska track:Oko za oko album:Wznieś serce: 0
# 590 artist:Ryszard Rynkowski track:Widzisz Marto album:Złota kolekcja: Ale filmy!: 0
# 591 artist:Ryszard Rynkowski track:Życie jest nowelą album:Audiobiografia 2: 0
# 592 artist:Ryszard Rynkowski track:Zwierzenia Ryśka czyli jedzie pociąg z... album:Audiobiografia 2: 0
# 593 artist:Patrycja Kosiarkiewicz track:Nie jestem byle co album:Upalne granie bez cienia mówienia w radiu zet: 0
# 594 artist:Edyta Bartosiewicz track:Siedem mórz, siedem lądów album:Upalne granie bez cienia mówienia w radiu zet: 0
# 595 artist:Justyna Steczkowska track:Dziewczyna szamana album:Lata dziewięćdziesiąte - Moja i twoja nadzieja: 0
# 596 artist:Marek Grechuta track:Gdziekolwiek album:Droga za widnokres: 1
# 597 artist:Marek Grechuta track:Krajobraz z wilgą i ludzie album:Droga za widnokres: 1
# 598 artist:Marek Grechuta track:W ciszy poranka (live) album:Droga za widnokres: 0
# 599 artist:Ryszard Rynkowski track:Kołysanki strachanki album:Laleczka z saskiej porcelany: 0
# 600 artist:Justyna Steczkowska track:Za dużo wiesz album:The Best Polish Songs… Ever! Volume 2: 0
# 601 artist:Justyna Steczkowska track:Oko za oko album:Piątki na piątki w Radiu Zet: 0
# 602 artist:Natalia Kukulska track:Daleki brzeg album:Piątki na piątki w Radiu Zet: 0
# 603 artist:Maryla Rodowicz track:Sex i kasa album:Piątki na piątki w Radiu Zet: 0
# 605 artist:Nosowska track:Nim stanie się tak album:Piątki na piątki w Radiu Zet: 0
# 606 artist:Piotr Szczepanik track:Zanim zaśniesz album:Wspomnienia: 0
# 607 artist:Piotr Szczepanik track:Nie zabłądzisz album:Wspomnienia: 0
# 608 artist:Piotr Szczepanik track:Każdy kogoś kocha album:Wspomnienia: 0
# 609 artist:Stan Borys track:Spacer dziką plażą album:Złote przeboje polskiej piosenki: lata 70: 0
# 610 artist:Irena Santor track:Nalej mi wina album:Platynowa kolekcja: Złote przeboje: 0
# 611 artist:Irena Santor track:Nalej mi wina album:Platynowa kolekcja: Złote przeboje: 0
# 612 artist:Maryla Rodowicz track:Małgośka album:Platynowa kolekcja: Złote przeboje: 0
# 613 artist:Maryla Rodowicz track:Małgośka album:Platynowa kolekcja: Złote przeboje: 0
# 614 artist:Justyna Steczkowska track:Smutny deszczyk album:Mezalianse: 0
# 615 artist:Justyna Steczkowska track:Upiorny twist album:Mezalianse: 0
# 616 artist:Alibabki track:Your Grey Eyes album:Bird Songs: 0
# 617 artist:Czesław Niemen track:Cztery ściany świata album:Aerolit: 0
# 618 artist:Czesław Niemen track:Kamyk album:Aerolit: 0
# 619 artist:Stan Borys track:Spacer dziką plażą album:Największe Gwiazdy - Złote przeboje: 0
# 620 artist:Ryszard Rynkowski track:Szczęśliwej drogi już czas album:Największe Gwiazdy - Złote przeboje: 0
# 621 artist:Stan Borys track:To ziemia album:Złota kolekcja - lata sześćdziesiąte - Kwiaty we włosach: 0
# 622 artist:Marek Grechuta track:Nie chodź dziewczyno do miasta album:Złota kolekcja - lata sześćdziesiąte - Kwiaty we włosach: 0
# 623 artist:Zakopower track:Boso album:Boso: 1
# 624 artist:Zakopower track:Kropla album:Boso: 1
# 625 artist:Kasia Cerekwicka track:Potrafię kochać album:Po polsku o miłości, Volume 2: 0
# 626 artist:Renata Dąbkowska track:Tatatara album:Po polsku o miłości, Volume 2: 0
# 627 artist:Kasia Cerekwicka track:Wszystko co mam album:Mozaika: 0
# 628 artist:Kasia Cerekwicka track:Kobieta jest jak księżyc album:Mozaika: 0
# 629 artist:Kasia Cerekwicka track:Noc to taka gra album:Mozaika: 0
# 630 artist:K.A.S.A. track:Bejbe album:№ 3: 0
# 631 artist:K.A.S.A. track:Wszyscy kochają kasę album:№ 3: 0
# 632 artist:K.A.S.A. track:Esencja kwadratu album:№ 3: 0
# 633 artist:K.A.S.A. track:Polscy biali album:№ 3: 0
# 634 artist:K.A.S.A. track:Przetańcz cały night album:№ 3: 0
# 635 artist:Kasia Cerekwicka track:Ballada o miłości album:FE-MALE: 1
# 636 artist:Kasia Cerekwicka track:Siłaczka album:FE-MALE: 1
# 637 artist:Kasia Cerekwicka track:Finał album:FE-MALE: 1
# 638 artist:Donatan track:Z samym sobą album:Równonoc: 2
# 639 artist:Donatan track:Z dziada pradziada album:Równonoc: 2
# 640 artist:Donatan track:Szukaj jej tu album:Równonoc: 2
# ...
# 5537 artist:Czesław Niemen track:Dobranoc album:Pamiętam Ten Dzień: 0
# 5538 artist:Czesław Niemen track:Czy Mnie Jeszcze Pamiętasz album:Pamiętam Ten Dzień: 0
# 5539 artist:Czesław Niemen track:Hej Dziewczyno, Hej album:Pamiętam Ten Dzień: 0
# 5540 artist:Czesław Niemen track:Sen O Warszawie album:Pamiętam Ten Dzień: 0
# 5541 artist:Czesław Niemen track:Wspomnienie album:Pamiętam Ten Dzień: 0
# 5542 artist:Grzegorz Markowski track:To album:Now That's What I Call Music 01: 0
# 5543 artist:Edyta Bartosiewicz track:Before You Came album:Teraz albo nigdy! (Piosenki z serialu): 0
# 5544 artist:Nosowska track:Nim stanie się tak, jak gdyby nigdy nic nie było album:Teraz albo nigdy! (Piosenki z serialu): 0
# 5545 artist:Czesław Niemen track:Jednego Serca album:Die 100 besten Ostsongs: 0
# 5546 artist:K.A.S.A. track:En.U.Da.A. album:Reklama: 0
# 5547 artist:K.A.S.A. track:Kasanova album:Reklama: 0
# 5548 artist:K.A.S.A. track:Jak należy korzystać z malucha album:Reklama: 0
# 5549 artist:K.A.S.A. track:Szpital dla chorych psychicznie i nerwowo album:Reklama: 0
# 5550 artist:K.A.S.A. track:Reklama album:Reklama: 0
# 5551 artist:K.A.S.A. track:Mikrofo-On album:Reklama: 0
# 5552 artist:K.A.S.A. track:Sex i kasa album:Reklama: 0
# 5553 artist:K.A.S.A. track:Łoj co za kobita album:Reklama: 0
# 5554 artist:K.A.S.A. track:En.U.Da.A. M.I.X (Muffin Masta mix) album:Reklama: 0
# 5555 artist:K.A.S.A. track:Reklama Mix (Garaż mix) album:Reklama: 0
# 5556 artist:K.A.S.A. track:No kto? album:Reklama: 0
# 5557 artist:Natalia Kukulska track:Ani słowa album:Best Of Disney: 0
# 5558 artist:Andrzej Lampert track:Droga sześć i sześć album:Best Of Disney: 0
# 5559 artist:Krzysztof Kiljański track:Podejrzani zakochani album:O miłości po polsku, czyli największe przeboje polskich komedii romantycznych: 0
# 5560 artist:Natalia Kukulska track:Wierność jest nudna album:O miłości po polsku, czyli największe przeboje polskich komedii romantycznych: 1
# 5561 artist:K.A.S.A. track:Leń album:Polska młodzież śpiewa klasyków: 0
# 5562 artist:Andrzej Lampert track:I Will Be With You (Where the Lost Ones Go) album:Symphony: 0
# 5563 artist:Nosowska track:My Soul's Among to Lions album:Ladies and Gentlemen on Acid: 1
# 5564 artist:Ryszard Rynkowski track:Wypijmy za błędy album:Królowie polskiej piosenki: 0
# 5565 artist:Ryszard Rynkowski track:Szczęśliwej drogi, już czas album:Królowie polskiej piosenki: 0
# 5566 artist:Ryszard Rynkowski track:Swobodny blues album:Królowie polskiej piosenki: 0
# 5567 artist:Ryszard Rynkowski track:Czemu nie tańczę na ulicach album:Królowie polskiej piosenki: 0
# 5568 artist:Ryszard Rynkowski track:Nie budźcie marzeń ze snu album:Królowie polskiej piosenki: 0
# 5569 artist:Ryszard Rynkowski track:Zwierzenia Ryśka, czyli jedzie pociąg z daleka album:Królowie polskiej piosenki: 0
# 5570 artist:Ryszard Rynkowski track:Wyspa album:Królowie polskiej piosenki: 0
# 5571 artist:Seweryn Krajewski track:Płoną góry, płoną lasy album:Królowie polskiej piosenki: 0
# 5572 artist:Seweryn Krajewski track:Kiedy mnie już nie będzie album:Królowie polskiej piosenki: 0
# 5573 artist:Seweryn Krajewski track:Uciekaj moje serce album:Królowie polskiej piosenki: 0
# 5574 artist:Seweryn Krajewski track:Baw mnie album:Królowie polskiej piosenki: 0
# 5575 artist:Seweryn Krajewski track:Niebo z moich stron album:Królowie polskiej piosenki: 0
# 5576 artist:Piotr Szczepanik track:Goniąc kormorany album:Królowie polskiej piosenki: 0
# 5577 artist:Piotr Szczepanik track:Żółte kalendarze album:Królowie polskiej piosenki: 0
# 5578 artist:Piotr Szczepanik track:Zabawa podmiejska album:Królowie polskiej piosenki: 0
# 5579 artist:Piotr Szczepanik track:Dzień niepodobny do dnia album:Królowie polskiej piosenki: 0
# 5580 artist:Piotr Szczepanik track:Zanim zaśniesz album:Królowie polskiej piosenki: 0
# 5581 artist:Piotr Szczepanik track:Chciałbym kiedyś album:Królowie polskiej piosenki: 0
# 5582 artist:Piotr Szczepanik track:Tęsknię za Tobą album:Królowie polskiej piosenki: 0
# 5583 artist:Piotr Szczepanik track:Kochać album:Królowie polskiej piosenki: 0
# 5584 artist:Piotr Szczepanik track:Puste koperty album:Królowie polskiej piosenki: 0
# 5585 artist:Piotr Szczepanik track:Co się jutro zdarzyć ma album:Królowie polskiej piosenki: 0
# 5586 artist:Seweryn Krajewski track:Kołysanka dla Okruszka album:Królowie polskiej piosenki: 0
# 5587 artist:Seweryn Krajewski track:Bądź wśród nas album:Królowie polskiej piosenki: 0
# 5588 artist:Seweryn Krajewski track:Lubię ten smutek album:Królowie polskiej piosenki: 0
# 5589 artist:Seweryn Krajewski track:Zabierz mnie stąd album:Królowie polskiej piosenki: 0
# 5590 artist:Sławek Uniatowski track:5 rano album:Smooth Jazz Cafe 18: 0
# 5591 artist:Nosowska track:Boso (Kayax XX rework) album:Kayax XX Rework: 2
# 5592 artist:Zakopower track:2015 (Kayax XX rework) album:Kayax XX Rework: 2
# 5593 artist:Edyta Bartosiewicz track:Egoiści album:The Best Film ...Ever!: 0
# 5594 artist:Maryla Rodowicz track:Kleine Eisenbahnballade album:Ein Kessel Buntes – Das Beste: 0
# 5595 artist:Krzysztof Kiljański track:Kto tak ładnie kradnie jak on album:Gadu Gadu [Special Edition]: 0
# 5596 artist:Justyna Steczkowska track:Na koniec świata album:The Best Film ...Ever!: 0
# 5597 artist:Natalia Kukulska track:Zakochani album:The Best Film ...Ever!: 0
# 5598 artist:Ryszard Rynkowski track:Bóg się rodzi album:Kolędy polskie: 0
# 5599 artist:Ryszard Rynkowski track:Gdy się Chrystus rodzi album:Kolędy polskie: 0
# 5600 artist:Ryszard Rynkowski track:W żłobie leży album:Kolędy polskie: 0
# 5601 artist:Stan Borys track:Niczyj album:Niczyj: 0
# 5602 artist:Grzegorz Markowski track:07 zgłoś się album:Ale Seriale!: 0
# 5603 artist:Czesław Niemen track:Rodzina Leśniewskich album:Ale Seriale!: 0
# 5604 artist:Seweryn Krajewski track:Jan Serce album:Ale Seriale!: 0
# 5605 artist:Ryszard Rynkowski track:Klan ("Życie jest nowelą") album:Ale Seriale!: 0
# 5606 artist:Edyta Bartosiewicz track:Jenny album:Być Kobietą: 0
# 5607 artist:Irena Santor track:Powrócisz Tu album:Być Kobietą: 0
# 5608 artist:Justyna Steczkowska track:Oko Za Oko album:Być Kobietą: 0
# 5609 artist:Nosowska track:Jeśli Wiesz Co Chcę Powiedzieć album:Być Kobietą: 0
# 5610 artist:Patrycja Kosiarkiewicz track:Jak Ja Wierzę album:Być Kobietą: 0
# 5611 artist:Natalia Kukulska track:Piosenka Światłoczuła album:Być Kobietą: 0
# 5612 artist:Nosowska track:2019 - Sobie i wam album:Męskie Granie 2010-2019: 0
# 5613 artist:Piotr Szczepanik track:Kochać album:60 Lat Polskich Nagran: 1
# 5614 artist:Piotr Szczepanik track:Co Się Jutro Zdarzyć Ma album:60 Lat Polskich Nagran: 1
# 5615 artist:Irena Santor track:Serce album:60 Lat Polskich Nagran: 1
# 5616 artist:Irena Santor track:Tych Lat Nie Odda Nikt album:60 Lat Polskich Nagran: 1
# 5617 artist:Marek Grechuta track:Dni, Ktorych Nie Znamy album:60 Lat Polskich Nagran: 1
# 5618 artist:Marek Grechuta track:Prawo album:Dziesięć ważnych słów: 0
# 5619 artist:Nosowska track:Kto? album:Męskie Granie 2014: 1
# 5620 artist:Czesław Niemen track:Jamais album:Jamais: 0
# 5621 artist:Czesław Niemen track:Varsovie album:Jamais: 0
# 5622 artist:Czesław Niemen track:Hey Les Filles album:Jamais: 0
# 5623 artist:Czesław Niemen track:Peut-Etre album:Jamais: 0
# 5624 artist:Czesław Niemen track:Io Senza Lei album:Io Senza Lei: 0
# 5625 artist:Czesław Niemen track:Arcobaleno album:Io Senza Lei: 0
# 5626 artist:Czesław Niemen track:Człowiek jam niewdzięczny album:Niemen: 0
# 5627 artist:Czesław Niemen track:Aerumnarum Plenus album:Niemen: 0
# 5628 artist:Czesław Niemen track:Italiam, Italiam album:Niemen: 0
# 5629 artist:Czesław Niemen track:Enigmatyczne impresje album:Niemen: 0
# 5630 artist:Czesław Niemen track:Nie jesteś moja album:Niemen: 0
# 5631 artist:Czesław Niemen track:Wróć jeszcze dziś album:Niemen: 0
# 5632 artist:Czesław Niemen track:Mój pejzaż album:Niemen: 0
# 5633 artist:Czesław Niemen track:Sprzedaj mnie wiatrowi album:Niemen: 0
# 5634 artist:Czesław Niemen track:Zechcesz mnie, zechcesz album:Niemen: 0
# 5635 artist:Czesław Niemen track:Chwila ciszy album:Niemen: 0
# 5636 artist:Czesław Niemen track:Muzyko moja album:Niemen: 0
# 5637 artist:Nosowska track:awejniak album:Lata Dwudzieste: 0
# 5638 artist:Alibabki track:Rosołek album:Złote Przeboje: 0
# 5639 artist:Alibabki track:Pajacyk album:Złote Przeboje: 0
# 5640 artist:Alibabki track:Kwiat Jednej Nocy album:Złote Przeboje: 0
# 5641 artist:Alibabki track:Samotna Rękawiczka album:Złote Przeboje: 0
# 5642 artist:Alibabki track:Szary Kolor Twoich Oczu album:Złote Przeboje: 0
# 5643 artist:Alibabki track:To Ziemia album:Złote Przeboje: 0
# 5644 artist:Alibabki track:Nie Żądam Wiele album:Złote Przeboje: 0
# 5645 artist:Alibabki track:Słońce W Chmurach Łazi album:Złote Przeboje: 0
# 5646 artist:Alibabki track:Gdy Zmęczeni Wracamy Z Pól album:Złote Przeboje: 0
# 5647 artist:Alibabki track:Jak Dobrze Mieć Sąsiada album:Złote Przeboje: 0
# 5648 artist:Alibabki track:Może Cię Spotkam album:Złote Przeboje: 0
# 5649 artist:Alibabki track:Witaj Rzeko album:Złote Przeboje: 0
# 5650 artist:Alibabki track:Kiedyk Pasła Budło album:Złote Przeboje: 0
# 5651 artist:Alibabki track:Grajmy Sobie W Zielone album:Złote Przeboje: 0
# 5652 artist:Alibabki track:Dom W Malwy Malowany album:Złote Przeboje: 0
# 5653 artist:Alibabki track:Odkładana Miłość album:Złote Przeboje: 0
# 5654 artist:Alibabki track:Tango Zalotne Przeleć Mnie album:Złote Przeboje: 0
# 5655 artist:Alibabki track:Zagrajmy W Kości Jeszcze Raz album:Złote Przeboje: 0
# 5656 artist:Alibabki track:Pani, Ty Jesteś Urocza album:Złote Przeboje: 0
# 5657 artist:Alibabki track:Kapitańskie Tango album:Złote Przeboje: 0
# 5658 artist:Irena Santor track:Embarras album:Embarras: 0
# 5659 artist:Irena Santor track:Każda Miłość Jest Pierwsza album:Embarras: 0
# 5660 artist:Irena Santor track:Odrobinę Szczęścia W Miłości album:Embarras: 0
# 5661 artist:Irena Santor track:Serce album:Embarras: 0
# 5662 artist:Irena Santor track:Jalousie album:Embarras: 0
# 5663 artist:Irena Santor track:Jesienne Róże album:Embarras: 0
# 5664 artist:Irena Santor track:Tango Milonga album:Embarras: 0
# 5665 artist:Irena Santor track:Nie Mów Mi Sentymentalnych Słów album:Embarras: 0
# 5666 artist:Irena Santor track:Jesienna Rozłąka album:Embarras: 0
# 5667 artist:Irena Santor track:Ździebełko Ciepełka album:Embarras: 0
# 5668 artist:Irena Santor track:Tych Lat Nie Odda Nikt album:Embarras: 0
# 5669 artist:Irena Santor track:Jak Przygoda, To Tylko W Warszawie album:Embarras: 0
# 5670 artist:Irena Santor track:Walczyk Warszawy album:Embarras: 0
# 5671 artist:Irena Santor track:Małe Mieszkanko Na Mariensztacie album:Embarras: 0
# 5672 artist:Irena Santor track:Na Prawo Most, Na Lewo Most album:Embarras: 0
# 5673 artist:Irena Santor track:Kamienne Schodki album:Embarras: 0
# 5674 artist:Irena Santor track:Warszawa, Ja I Ty album:Embarras: 0
# 5675 artist:Irena Santor track:Pójdę Na Stare Miasto album:Embarras: 0
# 5676 artist:Irena Santor track:Maleńki Znak album:Embarras: 0
# 5677 artist:Irena Santor track:Powrócisz Tu album:Embarras: 0
# 5678 artist:Irena Santor track:Embarras album:Embarras: 0
# 5679 artist:Czesław Niemen track:Obłuda album:List do R.: 0
# 5680 artist:Maryla Rodowicz track:Hej, Träume (Jaworowy most) album:Die DT64 Singles: 0
# 5681 artist:Krzysztof Kiljański track:Od swiat do swiat album:The Best Christmas …Ever!: 0
# 5682 artist:Maryla Rodowicz track:What Is Time album:Piknik: 0
# 5683 artist:Justyna Steczkowska track:Sama (Poland) album:Eurovision Song Contest 1956-2009 All Songs-EmpAta: 0
# 5684 artist:Maryla Rodowicz track:Сядь в любой поезд album:С Новым годом!: 0
# 5685 artist:Maryla Rodowicz track:Сядь в любой поезд album:С Новым годом!: 0
# 5686 artist:Maryla Rodowicz track:Сядь в любой поезд album:С Новым годом!: 0
# 5687 artist:Sławek Uniatowski track:Twoje ja album:Vaiana: Skarb oceanu piosenki: 0
# 5688 artist:Maryla Rodowicz track:Сядь в любой поезд album:Золотой шлягер: 0
# 5689 artist:Nosowska track:Uroda (prolog) album:Osiecka: 0
# 5690 artist:Nosowska track:Na całych jeziorach Ty album:Osiecka: 0
# 5691 artist:Nosowska track:Nim wstanie dzień album:Osiecka: 0
# 5692 artist:Nosowska track:Kokaina album:Osiecka: 0
# 5693 artist:Nosowska track:Jeszcze zima album:Osiecka: 0
# 5694 artist:Nosowska track:Uroda album:Osiecka: 0
# 5695 artist:Nosowska track:Kto tam u Ciebie jest? album:Osiecka: 0
# 5696 artist:Nosowska track:Zielono mi album:Osiecka: 0
# 5697 artist:Nosowska track:Uciekaj, moje serce album:Osiecka: 0
# 5698 artist:Nosowska track:Jesień na Saskiej album:Osiecka: 0
# 5699 artist:Nosowska track:Na kulawej naszej barce album:Osiecka: 0
# 5700 artist:Krzysztof Kiljański track:Zawsze obok mnie album:CD Club Promo Only 7/2013: 0
# 5701 artist:Nosowska track:Uroda (prolog) album:Agnieszka Osiecka: 0
# 5702 artist:Nosowska track:Na całych jeziorach Ty album:Agnieszka Osiecka: 0
# 5703 artist:Nosowska track:Nim wstanie dzień album:Agnieszka Osiecka: 0
# 5704 artist:Nosowska track:Kokaina album:Agnieszka Osiecka: 0
# 5705 artist:Nosowska track:Jeszcze zima album:Agnieszka Osiecka: 0
# 5706 artist:Nosowska track:Uroda album:Agnieszka Osiecka: 0
# 5707 artist:Nosowska track:Kto tam u Ciebie jest? album:Agnieszka Osiecka: 0
# 5708 artist:Nosowska track:Zielono mi album:Agnieszka Osiecka: 0
# 5709 artist:Nosowska track:Uciekaj, moje serce album:Agnieszka Osiecka: 0
# 5710 artist:Nosowska track:Jesień na Saskiej album:Agnieszka Osiecka: 0
# 5711 artist:Nosowska track:Na kulawej naszej barce album:Agnieszka Osiecka: 0
# 5712 artist:Nosowska track:Ledwie wczoraj album:Męskie Granie 2023: 0
# 5713 artist:Nosowska track:Miałem już nie tańczyć album:Męskie Granie 2023: 0
# 5714 artist:Stan Borys track:Noc Ubogiego Człowieka album:Niczyj: 0
# 5715 artist:Stan Borys track:Zmęczony Burz Szaleństwem album:Niczyj: 0
# 5716 artist:Stan Borys track:Życie Moje album:Niczyj: 0
# 5717 artist:Stan Borys track:Wszystko album:Niczyj: 0
# 5718 artist:Stan Borys track:Litania album:Niczyj: 0
# 5719 artist:Stan Borys track:Kochać I Tracić album:Niczyj: 0
# 5720 artist:Stan Borys track:Wypłakałem Oczy Niebieskie album:Niczyj: 0
# 5721 artist:Stan Borys track:Skończoność album:Niczyj: 0
# 5722 artist:Stan Borys track:Zmęczenie album:Niczyj: 0
# 5723 artist:Stan Borys track:Moja Piosenka (Do Kraju Tego) album:Niczyj: 0
# 5724 artist:Czesław Niemen track:Sen O Warszawie (Invent Edit) album:Polish Edits #3: 0
# 5725 artist:Czesław Niemen track:Song For Mohindar album:Polish Edits # 6: 0
# 5726 artist:Stan Borys track:Krzyczę Przez Sen album:Krzyczę Przez Sen: 0
# 5727 artist:Stan Borys track:Ballada O Dwóch Siostrach album:Krzyczę Przez Sen: 0
# 5728 artist:Stan Borys track:Ikona album:Krzyczę Przez Sen: 0
# 5729 artist:Stan Borys track:Kyrie album:Krzyczę Przez Sen: 0
# 5730 artist:Stan Borys track:Song Garbusa album:Krzyczę Przez Sen: 0
# 5731 artist:Stan Borys track:Mój Przyjaciel Deszcz album:Krzyczę Przez Sen: 0
# 5732 artist:Stan Borys track:W Twoje Oczy Zapatrzony album:Krzyczę Przez Sen: 0
# 5733 artist:Stan Borys track:Gdybym Znalazł... album:Krzyczę Przez Sen: 0
# 5734 artist:Stan Borys track:Listów Pożółkła Biel album:Krzyczę Przez Sen: 0
# 5735 artist:Stan Borys track:W Jaki Sposób Powstał "Straszny Dwór" album:Krzyczę Przez Sen: 0
# 5736 artist:Ryszard Rynkowski track:Wyspa album:Galimatias: Gala piosenki aktorskiej Wrocław 1989-95: 0
# 5737 artist:Donatan track:Introdukcja album:Hiper / Chimera: 2
# 5738 artist:Donatan track:Hiper / Chimera album:Hiper / Chimera: 2
# 5739 artist:Donatan track:Brać album:Hiper / Chimera: 2
# 5740 artist:Donatan track:Sztorm album:Hiper / Chimera: 2
# 5741 artist:Donatan track:Ten czas album:Hiper / Chimera: 2
# 5742 artist:Donatan track:Slavica album:Hiper / Chimera: 2
# 5743 artist:Donatan track:Tłusty czarny kot album:Hiper / Chimera: 2
# 5744 artist:Donatan track:Cicha woda album:Hiper / Chimera: 2
# 5745 artist:Donatan track:Cofnąć czas album:Hiper / Chimera: 2
# 5746 artist:Donatan track:My Słowianie album:Hiper / Chimera: 2
# 5747 artist:Donatan track:Papierowy ład album:Hiper / Chimera: 2
# 5748 artist:Donatan track:B.I.T. album:Hiper / Chimera: 2
# 5749 artist:Donatan track:Nie pozwól album:Hiper / Chimera: 2
# 5750 artist:Donatan track:Efekt motyla album:Hiper / Chimera: 2
# 5751 artist:Donatan track:Nie lubimy robić album:Hiper / Chimera: 2
# 5752 artist:Donatan track:WinyLova album:Hiper / Chimera: 0

# %% [markdown]
# ### Graf

# %%
import networkx as nx, plotly.graph_objects as go

# %%
G = nx.from_pandas_edgelist(tracks, 'track', 'artist')
pos = nx.spring_layout(G)

artist_nodes, track_nodes, track_nodes_unknown = ([], [], [])
for node in G.nodes:

    node_data = {

        'x': pos[node][0],
        'y': pos[node][1],
        'text': artist_labels.loc[node].iloc[0] if node in artist_labels.index 
            else track_labels.loc[node].iloc[0] if node in track_labels.index
            else node
    }

    if node in artist_labels.index:
        artist_nodes.append(node_data)
        continue

    if spotify_searches.loc[spotify_searches['track'] == node, 'spotify_id'].iloc[0]:
        node_data['popularity'] = spotify_searches.loc[spotify_searches['track'] == node, 'popularity'].iloc[0]
        track_nodes.append(node_data)
        continue

    track_nodes_unknown.append(node_data)

artist_nodes = pd.DataFrame(artist_nodes)
track_nodes = pd.DataFrame(track_nodes)
track_nodes_unknown = pd.DataFrame(track_nodes_unknown)

edges = pd.DataFrame({
    'x': [coord for edge in G.edges for coord in (pos[edge[0]][0], pos[edge[1]][0], None)], 
    'y': [coord for edge in G.edges for coord in (pos[edge[0]][1], pos[edge[1]][1], None)]
})

# %%
fig = go.Figure().update_layout(
    title=f"{artist} i kolaboracje",
    autosize=False,
    margin=dict(l=0, r=50, b=0, t=50, pad=0),
    paper_bgcolor="White",
    plot_bgcolor="White",
    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)
)

fig.add_trace(go.Scatter(
    name='krawędzie',
    x=edges['x'], y=edges['y'],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines',
    opacity=0.5
))

fig.add_trace(go.Scatter(
    name='autorzy',
    x=artist_nodes['x'], 
    y=artist_nodes['y'],
    hoverinfo='text', text=artist_nodes['text'],

    mode='markers', marker=dict(
        symbol='star',
        color='Red',
        size=10
    )
))
 
fig.add_trace(go.Scatter(
    name='tytuły',
    x=track_nodes['x'], 
    y=track_nodes['y'],
    hoverinfo='text', text=track_nodes['text'],
    mode='markers', marker=dict(
        symbol='circle',
        color='Green',
        size=track_nodes['popularity']/5

    )
))

fig.add_trace(go.Scatter(
    name='tytuły o nieznanej popularności',
    x=track_nodes_unknown['x'],
    y=track_nodes_unknown['y'],
    hoverinfo='text', text=track_nodes_unknown['text'],
    mode='markers', marker=dict(
        symbol='circle',
        color='Black',
        size=1,
        opacity=0.5
    )
))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/networkx/classes/graph.py in neighbors(self, n)
#    1353         try:
# -> 1354             return iter(self._adj[n])
#    1355         except KeyError as err:
#
# KeyError: 'Czesław Niemen'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# /tmp/ipykernel_2460/2707737678.py in <module>
#      27         symbol='star',
#      28         color='Red',
# ---> 29         size=sum([len(nx.neighbors(G, node)) for node in artist_nodes['text']])/2
#      30     )
#      31 ))
#
# /tmp/ipykernel_2460/2707737678.py in <listcomp>(.0)
#      27         symbol='star',
#      28         color='Red',
# ---> 29         size=sum([len(nx.neighbors(G, node)) for node in artist_nodes['text']])/2
#      30     )
#      31 ))
#
# ~/.local/lib/python3.10/site-packages/networkx/classes/function.py in neighbors(G, n)
#      76 def neighbors(G, n):
#      77     """Returns a list of nodes connected to node n."""
# ---> 78     return G.neighbors(n)
#      79
#      80
#
# ~/.local/lib/python3.10/site-packages/networkx/classes/graph.py in neighbors(self, n)
#    1354             return iter(self._adj[n])
#    1355         except KeyError as err:
# -> 1356             raise NetworkXError(f"The node {n} is not in the graph.") from err
#    1357
#    1358     @cached_property
#
# NetworkXError: The node Czesław Niemen is not in the graph.
